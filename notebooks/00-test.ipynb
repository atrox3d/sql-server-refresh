# %%
use [sample]
# Out:
# Commands completed successfully.

# %%
select * from dbo.tblPerson
# Out:
# (1 row affected)
# ID | Name | Email   | GenderId
# ---+------+---------+---------
# 1  | john | j@j.com | NULL
# (1 row)
