# %%
USE [sample];
GO
/*
    Best Practice: Stop "rows affected" noise
*/
SET NOCOUNT ON;

SELECT DB_NAME() AS db_name;
PRINT 'INFO | Initial Database Context: ' + DB_NAME();
GO
# Out:
# Commands completed successfully.
# INFO | Initial Database Context: sample
# db_name
# -------
# sample
# (1 row)

# %%
/*
************************************************************************************
    prepare data
************************************************************************************
*/
DELETE FROM sample.dbo.tblPerson;
-- GO
TRUNCATE TABLE sample.dbo.tblPerson;
-- GO
# Out:
# Commands completed successfully.

# %%
INSERT INTO sample.dbo.tblPerson
VALUES 
    (1, 'john',  'j@j.com',      1),
    (2, 'mary',  'm@m.com',      2),
    (3, 'simon', 's@s.com',      1),
    (4, 'sam',   'sam@sam.com',  1),
    (5, 'may',   'may@may.com',  1),
    (6, 'kerry', 'k@k.com',      3)
;

SELECT * FROM sample.dbo.tblPerson;
# Out:
# Commands completed successfully.
# ID | Name  | Email       | GenderId
# ---+-------+-------------+---------
# 1  | john  | j@j.com     | 1
# 2  | mary  | m@m.com     | 2
# 3  | simon | s@s.com     | 1
# 4  | sam   | sam@sam.com | 1
# 5  | may   | may@may.com | 1
# 6  | kerry | k@k.com     | 3
# (6 rows)
